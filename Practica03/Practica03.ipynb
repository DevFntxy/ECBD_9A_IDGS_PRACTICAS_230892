# %% [markdown]
# # Práctica 03: Análisis Exploratorio de Datos con Python y Jupyter Notebook
#
# **Programa de estudios:** Ingeniería en Desarrollo y Gestión de Software <br>
# **Asignatura:** Extracción de Conocimiento en Bases de Datos <br>
# **Docente:** M.T.I. Marco A. Ramírez Hernández <br>
# **Periodo:** Mayo - Agosto 2026 <br>
#
# ---
# ## Unidad 2: Preparacion de los Datos:
#
# **Nombre del estudiante:** Derek Sesni Carreño <br>
# **Matricula:** 230892 <br>
# **Grado y Grupo:** 9 A IDGS <br>

# %% [markdown]
# El estudiante  practicara como realizar un analisis de datos, utilizando el lenguaje de proggramacion de Python y Librerias comunes para la cargam
# manipulacion, analisis y visualizacion previa de un conjunto de datos (Dataset), para esta practica se utilizaran las librerias de:
#
# - Pandas
# - Numby
# - Seaborn
# - os
# - Matloip

# %% [markdown]
# 1. Importar las librerias necesarias para realizar el EDA:
#
# Comenzamos por importar la libreria que nos permitira manipular los datos del dataset extraidos de una duente de datos (datasource)

# %%
import pandas as pd
import numpy as plt
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# 2. Creamos un DataFrame. leyendo el archivo delimitado por (.CSC)

# %%
pokemon=pd.read_csv('./Pokemon.csv')

# %% [markdown]
# 3. Imprimimos el resultado de la lectura
#
# Este comando imprime en una tabla de las comluimunas y las filas del dataframe, siempre de manera estandar nos mostrara los 5 primeros y 5 uultimos del dataframe

# %%
pokemon
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      1            Bulbasaur    Grass  Poison    318  45      49       49
# 2      1            Bulbasaur    Grass  Poison    318  45      49       49
# 3      2              Ivysaur    Grass  Poison    405  60      62       63
# 4      2              Ivysaur    Grass  Poison    405  60      62       63
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 798  719              Diancie     Rock   Fairy    600  50     100      150
# 799  719  DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 800  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 801  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 802  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# 4. Obetener una muestra aleatoria de registros del dataframe usando el nediti **.sample**

# %%
pokemon.sample(7) ## toma 5 datos aleatorios de la lista
# Out:
#        #                       Name    Type 1   Type 2  Total  HP  Attack  \
# 41    33                   Nidorino    Poison      NaN    365  61      72
# 351  319                   Sharpedo     Water     Dark    460  70     120
# 372  337                   Lunatone      Rock  Psychic    440  70      55
# 516  462                  Magnezone  Electric    Steel    535  70      70
# 662  598                 Ferrothorn     Grass    Steel    489  74      94
# 10     6  CharizardMega Charizard X      Fire   Dragon    634  78     130
# 115  104                     Cubone    Ground      NaN    320  50      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 41        57       55       55     65           1      False
# 351       40       95       40     95           3      False
# 372       65       95       85     70           3      False
# 516      115      130       90     60           4      False
# 662      131       54      116     20           5      False
# ...

# %% [markdown]
# **Ejercicio 1 :** Obten una muestra de 50 pokemones

# %%
pokemon.sample(50) ## toma 5 datos aleatorios de la lista
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 443  395                   Empoleon     Water     Steel    530   84      86
# 522  468                   Togekiss     Fairy    Flying    545   85      50
# 390  354        BanetteMega Banette     Ghost       NaN    555   64     165
# 568  506                   Lillipup    Normal       NaN    275   45      60
# 600  537                 Seismitoad     Water    Ground    509  105      95
# 683  619                    Mienfoo  Fighting       NaN    350   45      85
# 27    19                    Rattata    Normal       NaN    253   30      56
# 2      1                  Bulbasaur     Grass    Poison    318   45      49
# 415  376                  Metagross     Steel   Psychic    600   80     135
# 749  678               MeowsticMale   Psychic       NaN    466   74      48
# 639  575                  Gothorita   Psychic       NaN    390   60      45
# ...

# %% [markdown]
# 5. Obtener una muestra de rangos definidos usando **.iloc**

# %%
pokemon_100_to_200 = pokemon.iloc[100:200]
pokemon_100_to_200
# Out:
#        #                   Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 100   90               Shellder     Water     NaN    305  30      65      100
# 101   91               Cloyster     Water     Ice    525  50      95      180
# 102   92                 Gastly     Ghost  Poison    310  30      35       30
# 103   93                Haunter     Ghost  Poison    405  45      50       45
# 104   94                 Gengar     Ghost  Poison    500  60      65       60
# ..   ...                    ...       ...     ...    ...  ..     ...      ...
# 195  178                   Xatu   Psychic  Flying    470  65      75       70
# 196  179                 Mareep  Electric     NaN    280  55      40       40
# 197  180                Flaaffy  Electric     NaN    365  70      55       55
# 198  181               Ampharos  Electric     NaN    510  90      75       85
# 199  181  AmpharosMega Ampharos  Electric  Dragon    610  90      95      105
#
# ...

# %% [markdown]
# 6. Como saber las columnas o atributos tiene un dataframe

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Campo Descripcion <br>
# **#** El ID o numero de identificacion del Pokemo
# **Name:** El nombre del Pokémon <br>
# **Type 1:** Se refiere a las partes elementales (tipos) asociados tanto al Pokémon como a sus movimientos. <br>
# **Type 2:** Los Pokémon pueden tener hasta 2 tipos (Pokémon de tipo dual); los movimientos solo pueden tener uno. <br>
# **Total:** Representa la suma de todos los stats, lo que te da una idea de qué tan “pesado” o fuerte es el Pokémon. <br>
# **HP** (Puntos de Salud): Es qué tanto aguante tiene un Pokémon antes de que lo dejen fuera de combate (se desmaya). <br>
# **Attack:** La fuerza física de los ataques del Pokémon. <br>
# **Defense:** Qué tanto aguanta el Pokémon contra los ataques físicos del rival. <br>
# **Sp. Atk:** Ataque Especial; el poder de los movimientos especiales del Pokémon. <br>
# **Sp. Def:** Defensa Especial; qué tan resistente es el Pokémon ante los ataques especiales. <br>
# **Speed** (Velocidad): El Pokémon que tenga más velocidad ataca primero. <br>
# **Generations:** Se refiere a la generación de la serie de juegos a la que pertenece. <br>
# **Legendary:** Indica si el Pokémon es Legendario o no (son bichos muy raros y poderosos). Es un valor booleano (sí/no). <br>

# %% [markdown]
# 7. Explorar la composicion y ausencia de datos (METADATA) con **.info**

# %% [markdown]
# La libreria de pandas, incluye un metodo que nos permite el tipo de datos y ausencia

# %%
pokemon.info
# Out:
# <bound method DataFrame.info of        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      1            Bulbasaur    Grass  Poison    318  45      49       49
# 2      1            Bulbasaur    Grass  Poison    318  45      49       49
# 3      2              Ivysaur    Grass  Poison    405  60      62       63
# 4      2              Ivysaur    Grass  Poison    405  60      62       63
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 798  719              Diancie     Rock   Fairy    600  50     100      150
# 799  719  DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 800  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 801  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 802  721            Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# 8. Limpieza de datos

# %% [markdown]
# Dependiendo del objeto del análisis algunas columnas o registro no serán necesarias en nuestro Dataframe, en este caso omitiremos los datos vacios, por los que eliminaremos la columna 'Type 2', y renombraremos la columna 'Type 1' por 'Type'.

# %%
del pokemon['Type 2']
pokemon.rename(columns={'Type 1':'Type'}, inplace= True)

# %% [markdown]
# pokemon

# %% [markdown]
# **Ejercicio 02** Consulta la Metadata de la actualización y compara los cambios con la anterior.

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 803 entries, 0 to 802
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           803 non-null    int64
#  1   Name        803 non-null    object
#  2   Type        803 non-null    object
#  3   Total       803 non-null    int64
#  4   HP          803 non-null    int64
#  5   Attack      803 non-null    int64
#  6   Defense     803 non-null    int64
#  7   Sp. Atk     803 non-null    int64
#  8   Sp. Def     803 non-null    int64
#  9   Speed       803 non-null    int64
#  10  Generation  803 non-null    int64
#  11  Legendary   803 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 69.9+ KB

# %% [markdown]
# **¿Que cambios vez?** Cambia el número de columnas del Dataframe. Esto se puede corroborar viendo el contador de la primera columna; el último numero es 11, cuando antes era 12. Igual la columna 'Type' es un renombre de la anterior llamada 'Type 1'. La columna 'Type 2' desaparecio.

# %% [markdown]
# 9. Visualizacion de los primeros datos usando el metodo **.head**

# %%
pokemon.head()
# Out:
#    #       Name   Type  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass    318  45      49       49       65       65     45
# 1  1  Bulbasaur  Grass    318  45      49       49       65       65     45
# 2  1  Bulbasaur  Grass    318  45      49       49       65       65     45
# 3  2    Ivysaur  Grass    405  60      62       63       80       80     60
# 4  2    Ivysaur  Grass    405  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1       True

# %% [markdown]
# **Ejercicio 03** Muestra los ultimos 10 registros del dataframe

# %%
pokemon.tail(10)
# Out:
#        #                 Name     Type  Total   HP  Attack  Defense  Sp. Atk  \
# 793  714               Noibat   Flying    245   40      30       35       45
# 794  715              Noivern   Flying    535   85      70       80       97
# 795  716              Xerneas    Fairy    680  126     131       95      131
# 796  717              Yveltal     Dark    680  126     131       95      131
# 797  718     Zygarde50% Forme   Dragon    600  108     100      121       81
# 798  719              Diancie     Rock    600   50     100      150      100
# 799  719  DiancieMega Diancie     Rock    700   50     160      110      160
# 800  720  HoopaHoopa Confined  Psychic    600   80     110       60      150
# 801  720   HoopaHoopa Unbound  Psychic    680   80     160       60      170
# 802  721            Volcanion     Fire    600   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 793       40     55           6      False
# ...

# %% [markdown]
# 10. Estadistica basudaca del dataframe

# %% [markdown]
# Pandas permite emitir un reporte de estadística básica (medidas de tendencia) sobre datos cuantitativos usando el comando **.describe.**

# %%
pokemon.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  803.000000  803.000000  803.000000  803.000000  803.000000  803.000000
# mean   361.463263  434.773350   69.186800   78.905355   73.767123   72.809465
# std    209.121317  119.885433   25.517633   32.436641   31.152098   32.664352
# min      1.000000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    182.500000  330.000000   50.000000   55.000000   50.000000   50.000000
# 50%    363.000000  450.000000   65.000000   75.000000   70.000000   65.000000
# 75%    538.500000  515.000000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.000000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  803.000000  803.000000  803.000000
# mean    71.895392   68.209215    3.315068
# std     27.780427   29.030744    1.664237
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %% [markdown]
# 11. Calcular el total de datos no puplicados (unicos) <br>
# Usaremos **.len()** como funcion para calcular la longitud del dataset y **unique** para excluir los duplicados
#
#  ***NOTA:*** No conciderar ID como un atributo de llave primaria, sino el total de columnas con un solo elemento u objeto.

# %% [markdown]
# Obteniendo los valores unicos por columna en este caso en la comlumna "Name"

# %%
len(pokemon.Name.unique())
# Out:
# 800

# %% [markdown]
# Obteniendo el total de objetos (Conjunto de atributos, estrictamente iguales) , unicos

# %%
total_unicos = len(pokemon.drop_duplicates())
total_unicos
# Out:
# 801

# %% [markdown]
# **Ejercicio 04** Obtener el total de IDs unicos en el dataset

# %%
len(pokemon["#"].unique())
# Out:
# 721

# %% [markdown]
# **Ejercicios 05:** Obtener el total tipos unicos de pokemon

# %%
len(pokemon.Type.unique())
# Out:
# 18

# %% [markdown]
# 12. Contabilizacion de Datos por Atributo

# %% [markdown]
#  Pandas nos permite agrupar los datos por atributos y contabilizar los totales usando .value_counts() <br>
# ¿Cuantos Pokemones hay por generaciom?

# %%
pokemon['Generation'].value_counts()
# Out:
# Generation
# 1    169
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %% [markdown]
# 13. Grafica de conteo de Pokemon agrupados por generacion

# %%
sns.countplot(x='Generation',data=pokemon,palette='nipy_spectral')
plt.title('Numero de pokemones agrupados por generacion')
# Out:
# C:\Users\PC-10\AppData\Local\Temp\ipykernel_6372\2493767951.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Generation',data=pokemon,palette='nipy_spectral')
# Text(0.5, 1.0, 'Numero de pokemones agrupados por generacion')

# %% [markdown]
# 14. Conteo de categoria por tipo

# %% [markdown]
# Deseas saber cuantos pokemones hay de cada tipo para eso utilizamos **value_countss**

# %%
pokemon.Type.value_counts()
# Out:
# Type
# Water       112
# Normal       98
# Grass        73
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# 15. Gráfico de distribución de Pokémon por tipo

# %% [markdown]
# Se generó un gráfico de barras utilizando la función countplot() de Seaborn para visualizar la cantidad de Pokémon pertenecientes a cada tipo, con un tamaño de figura de 15 × 5 pulgadas para mejorar la distribucion

# %%
plt.figure(figsize=(15,5))
sns.countplot(pokemon.Type,palette='twilight')
# Out:
# C:\Users\PC-10\AppData\Local\Temp\ipykernel_6372\4261650627.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(pokemon.Type,palette='twilight')
# <Axes: xlabel='count', ylabel='Type'>

# %% [markdown]
# **NOTA:** Debido a que la cantidad de Pokémon de tipo Agua y Normal es alta en comparación con el resto, los Pokémon respectivos siempre tendrán estadísticas totales más altas.

# %% [markdown]
# 16. Analizar la distribución de las estadísticas principales de los Pokémon mediante diagramas de caja.

# %% [markdown]
# Se generaron boxplots para las variables numéricas de combate (HP, Attack, Defense, Sp. Atk, Sp. Def y Speed). Se excluyeron las columnas de identificación y las variables categóricas que no aportan información a este análisis.

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.boxplot(data=pokemon.drop(['#','Total','Generation','Legendary'],axis=1),fliersize=3,palette='seismic')
plt.title('Boxplots for stats')
# Out:
# Text(0.5, 1.0, 'Boxplots for stats')

# %% [markdown]
# 17. Gráfico de violín de las estadísticas de los Pokémon

# %% [markdown]
# Primero se crea una figura de 10 × 6 pulgadas para mejorar la visualización de los datos.
#
# Posteriormente, se utiliza la función violinplot() de Seaborn para representar la distribución de las estadísticas numéricas de los Pokémon. Para ello, se eliminan las columnas **#** , **Total, Generation** y **Legendary**, ya que no forman parte de las estadísticas individuales que se desean analizar.
#
# La paleta de colores rocket se emplea para diferenciar visualmente cada variable representada

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=pokemon.drop(['#','Total','Generation','Legendary'],axis=1),palette='rocket')
plt.title('Violinplots for stats')
# Out:
# Text(0.5, 1.0, 'Violinplots for stats')

# %% [markdown]
# 18. Agrupación de estadísticas por tipo de Pokémon

# %% [markdown]
# Las estadísticas tienen una distribución similar,Visualicemos los Pokémon agrupados por tipo.

# %%
pokemon.groupby('Type').sum()
# Out:
#               #                                               Name  Total  \
# Type
# Bug       23080  CaterpieMetapodButterfreeWeedleKakunaBeedrillB...  26146
# Dark      14302  UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...  13818
# Dragon    15180  DratiniDragonairDragoniteAltariaAltariaMega Al...  17617
# Electric  15994  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...  19510
# Fairy      7642  ClefairyClefableCleffaTogepiTogeticSnubbullGra...   7024
# Fighting   9824  MankeyPrimeapeMachopMachokeMachampHitmonleeHit...  11244
# Fire      17025  CharmanderCharmeleonCharizardCharizardMega Cha...  23820
# Flying     2711  TornadusIncarnate FormeTornadusTherian FormeNo...   1940
# Ghost     15568  GastlyHaunterGengarGengarMega GengarMisdreavus...  14066
# Grass     24145  BulbasaurBulbasaurBulbasaurIvysaurIvysaurVenus...  30521
# Ground    11401  SandshrewSandslashDiglettDugtrioCuboneMarowakR...  14000
# Ice       10165  JynxArticunoSwinubPiloswineDelibirdSmoochumSno...  10403
# ...

# %% [markdown]
# 19. Obtención de la suma total de HP por tipo de Pokémon

# %% [markdown]
# Se agruparon los registros del conjunto de datos utilizando la variable **Type**. Posteriormente, se sumaron las estadísticas numéricas de cada grupo mediante la función **sum()**. Finalmente, se seleccionó la columna **HP** para obtener una serie que muestra la suma total de puntos de salud para cada tipo de Pokémon.

# %%
pokemon.groupby('Type').sum().HP
# En esta serie, los tipos están ordenados alfabéticamente.
# Out:
# Type
# Bug         3925
# Dark        2071
# Dragon      2666
# Electric    2631
# Fairy       1260
# Fighting    1886
# Fire        3635
# Flying       283
# Ghost       2062
# Grass       4859
# Ground      2361
# Ice         1728
# Normal      7573
# Poison      1883
# Psychic     4026
# Rock        2876
# Steel       1761
# Water       8071
# Name: HP, dtype: int64

# %% [markdown]
# 20. Identificación de los tipos de Pokémon presentes en el conjunto de datos

# %% [markdown]
# Identificar todos los tipos de Pokémon existentes en el conjunto de datos sin valores repetidos.

# %%
pokemon['Type'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# 21. Ordenamiento de Tipos (Type) por orden alfabetico

# %%
list_types=pokemon['Type'].unique().tolist() #Convierte el arregloi de ripos en una lista para aplicar ardenamiento
list_types.sort() #Ordena los elementos de forma adcendente por defecto
list_types
# Out:
# ['Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water']

# %% [markdown]
# 22. Calculando los datos para graficacion del total de estadisticas por cada tipo de Podemon,respentado el orden alfebetico previamente deginido

# %%
sns.set_theme(style="darkgrid")

stats = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

palettes = ['magma', 'ocean', 'vlag', 'copper', 'mako', 'winter']

# Agrupar una sola vez
pokemon_stats = pokemon.groupby('Type')[stats].sum()

plt.figure(figsize=(17, 17))

for k, stat in enumerate(stats, start=1):

    plt.subplot(3, 2, k)

    sns.barplot(
        x=pokemon_stats[stat],
        y=pokemon_stats.index,
        hue=pokemon_stats.index, # evita warning de palette
        palette=palettes[k-1],
        legend=False
    )

    plt.title(f'Total of {stat}')
    plt.xlabel(stat)
    plt.ylabel('Type')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ejercicio 6 :** Modificacion al DataSet original,para verificar el calculo de graficos dinamicos
#
#     Actividades:
#
# - Agregar una nueva estadistica denominada "Armor" (Arnmadura)
# - Modificar el Dataset original con valores sugeridos por la IA
# - Documentar la estadistica en la actividad(6)
# - Agregar 5 nuevos pokemones de una nueva categoria denominada "Artificial"
# - Modificar los parametros necesarios para la graficacion
# - Recalcular los graficos

# %%
pokemones=pd.read_csv('./Pokemon2.csv')

# %%
pokemones
# Out:
#        #                   Name      Type 1  Type 2  Total   HP  Attack  \
# 0      1              Bulbasaur       Grass  Poison    318   45      49
# 1      2                Ivysaur       Grass  Poison    405   60      62
# 2      3               Venusaur       Grass  Poison    525   80      82
# 3      3  VenusaurMega Venusaur       Grass  Poison    625   80     100
# 4      4             Charmander        Fire     NaN    309   39      52
# ..   ...                    ...         ...     ...    ...  ...     ...
# 802  720    HoopaHoopa Confined     Psychic   Ghost    600   80     110
# 803  720     HoopaHoopa Unbound     Psychic    Dark    680   80     160
# 804  721              Volcanion        Fire   Water    600   80     110
# 805  722                  Sesni  Artificial   Water    787   67     676
# 806  723                Chuchin   Artifical    Rock    288  122     211
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Evolution_Level
# ...

# %% [markdown]
# Se egrego el campo **Evolution_Level** para saber cuantas evoluciones tiene cada pokemon y en cual se encuentra

# %%
del pokemones['Type 2']
pokemones.rename(columns={'Type 1':'Type'}, inplace= True)

# %%
sns.set_theme(style="darkgrid")

stats = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed','Evolution_Level']

palettes = ['magma', 'ocean', 'vlag', 'copper', 'mako', 'winter', 'ocean']

# Agrupar una sola vez
pokemon_stats = pokemones.groupby('Type')[stats].sum()

plt.figure(figsize=(15, 30))

for k, stat in enumerate(stats, start=1):

    plt.subplot(4, 2, k)

    sns.barplot(
        x=pokemon_stats[stat],
        y=pokemon_stats.index,
        hue=pokemon_stats.index, # evita warning de palette
        palette=palettes[k-1],
        legend=False
    )

    plt.title(f'Total of {stat}')
    plt.xlabel(stat)
    plt.ylabel('Type')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, len(stats)*4))

for k, stat in enumerate(stats, start=1):

    plt.subplot(len(stats), 1, k)

    sns.stripplot(
        data=pokemon,
        x='Type',
        y=stat,
        hue='Type',
        palette='Dark2',
        legend=False,
        jitter=True
    )

    plt.title(f'{stat} for each type')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 7
#       3 for k, stat in enumerate(stats, start=1):
#       5     plt.subplot(len(stats), 1, k)
# ----> 7     sns.stripplot(
#       8         data=pokemon,
#       9         x='Type',
#      10         y=stat,
#      11         hue='Type',
#      12         palette='Dark2',
#      13         legend=False,
#      14         jitter=True
#      15     )
#      17     plt.title(f'{stat} for each type')
#      18     plt.xticks(rotation=45)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2082, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2074 def stripplot(
#    2075     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
# ...
